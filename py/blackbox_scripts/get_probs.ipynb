# %%
import pickle
import autograd.numpy as np
from viabel.family import mean_field_gaussian_variational_family
import pandas as pd

import matplotlib.pyplot as plt
import time

# %%
data = pd.read_csv("bodyfat.csv").drop("Density", axis=1)
data = data - data.mean()
y = data["Bodyfat"].values
# centre the response to adjust for no intercept
y = y - np.mean(y)

x = data.drop("Bodyfat", axis=1)

N = x.shape[0]
D = x.shape[1]

# %%
mc_samples = 100000
M = 100

klvi_probs_mc = np.zeros(shape=(D+1, M))
klvi_probs_sis = np.zeros(shape=(D+1, M))
klvi_probs_psis = np.zeros(shape=(D+1, M))

# %%
mf_gaussian_var_family = mean_field_gaussian_variational_family(D+1)

# %% [markdown]
# test

# %%
with open("./data/klvi_psis_"+str(1)+".pkl", 'rb') as f:
    [btemp, stemp, klvi_samples_temp, klvi_slw_temp, klvi_lw_temp, klvi_khat_temp, klvi_var_param] = pickle.load(f)

# %%
klvi_khat_temp
# Out:
# 1.0184602207943316

# %% [markdown]
# get probs

# %%
start = time.time()
for i in range(M):
    start_loop = time.time()
    with open("./data/klvi_psis_"+str(i)+".pkl", 'rb') as f:
        [btemp, stemp, klvi_samples_temp, klvi_slw_temp, klvi_lw_temp, klvi_khat_temp, klvi_var_param] = pickle.load(f)
    
    scaled_weights_sis = np.exp(klvi_lw_temp - max(klvi_lw_temp))
    scaled_weights_psis = np.exp(klvi_slw_temp - max(klvi_slw_temp))
    khat_temp = klvi_khat_temp
    
    for j in range(D+1):
        prob_mc_temp = 0
        prob_sis_temp = 0
        prob_psis_temp = 0
        
        samples_temp = klvi_samples_temp[:][j]
        
        for k in range(mc_samples):
            if (j < D and samples_temp[k] < btemp[0][j]) or (j == D and np.log(samples_temp[k]) < np.log(stemp[0])):
                # unadjusted monte carlo
                prob_mc_temp += 1
                
                # sis
                prob_sis_temp += scaled_weights_sis[k]
                
                # psis
                prob_psis_temp += scaled_weights_psis[k]
                    
        klvi_probs_mc[j, i] = prob_mc_temp / mc_samples
        klvi_probs_sis[j, i] = prob_sis_temp / sum(scaled_weights_sis)
        klvi_probs_psis[j, i] = prob_psis_temp / sum(scaled_weights_psis)
    
    end_loop = time.time()
    print("i = %i, khat = %f, loop time = %f, time elapsed = %f" % (i, khat_temp, end_loop-start_loop, end_loop-start))

end = time.time()
print("Total time taken: %f" % (end-start))
# Out:
# i = 0, khat = 0.935836, loop time = 2.346871, time elapsed = 2.346871
# i = 1, khat = 1.018460, loop time = 2.393808, time elapsed = 4.740678
# i = 2, khat = 1.030366, loop time = 2.173637, time elapsed = 6.914315
# i = 3, khat = 1.013094, loop time = 2.122551, time elapsed = 9.036866
# i = 4, khat = 0.961193, loop time = 2.376807, time elapsed = 11.413673
# i = 5, khat = 0.908996, loop time = 2.262211, time elapsed = 13.675884
# i = 6, khat = 0.965015, loop time = 2.280077, time elapsed = 15.956961
# i = 7, khat = 0.972603, loop time = 2.216018, time elapsed = 18.172980
# i = 8, khat = 0.957232, loop time = 2.340131, time elapsed = 20.513111
# i = 9, khat = 0.927676, loop time = 2.242042, time elapsed = 22.755153
# i = 10, khat = 1.075998, loop time = 2.242043, time elapsed = 24.997195
# i = 11, khat = 0.998283, loop time = 2.297174, time elapsed = 27.295371
# i = 12, khat = 0.926907, loop time = 2.605625, time elapsed = 29.900995
# i = 13, khat = 1.058416, loop time = 2.399184, time elapsed = 32.300180
# i = 14, khat = 0.987274, loop time = 2.459300, time elapsed = 34.759480
# i = 15, khat = 1.048573, loop time = 2.099871, time elapsed = 36.860352
# i = 16, khat = 0.919964, loop time = 2.333459, time elapsed = 39.193811
# i = 17, khat = 1.011030, loop time = 2.528302, time elapsed = 41.722113
# i = 18, khat = 0.921869, loop time = 2.393470, time elapsed = 44.116584
# i = 19, khat = 0.989925, loop time = 2.308562, time elapsed = 46.426147
# i = 20, khat = 0.986748, loop time = 2.414199, time elapsed = 48.840346
# i = 21, khat = 0.945005, loop time = 2.342926, time elapsed = 51.183271
# i = 22, khat = 1.014793, loop time = 2.305500, time elapsed = 53.489773
# i = 23, khat = 0.984137, loop time = 2.230536, time elapsed = 55.720309
# i = 24, khat = 0.980390, loop time = 2.454951, time elapsed = 58.175260
# i = 25, khat = 1.001409, loop time = 2.317256, time elapsed = 60.493517
# i = 26, khat = 0.971065, loop time = 2.081888, time elapsed = 62.575405
# i = 27, khat = 1.049475, loop time = 2.233773, time elapsed = 64.809177
# i = 28, khat = 0.972754, loop time = 2.328299, time elapsed = 67.138478
# i = 29, khat = 1.037798, loop time = 2.306123, time elapsed = 69.445594
# i = 30, khat = 1.023806, loop time = 2.206008, time elapsed = 71.651602
# i = 31, khat = 1.012915, loop time = 2.235863, time elapsed = 73.887465
# i = 32, khat = 0.988883, loop time = 2.198199, time elapsed = 76.086665
# i = 33, khat = 1.081775, loop time = 2.437220, time elapsed = 78.523885
# i = 34, khat = 0.907737, loop time = 2.484622, time elapsed = 81.008507
# i = 35, khat = 0.954013, loop time = 2.209266, time elapsed = 83.218773
# i = 36, khat = 1.027922, loop time = 2.251050, time elapsed = 85.469823
# i = 37, khat = 1.041334, loop time = 2.320121, time elapsed = 87.789944
# i = 38, khat = 0.963217, loop time = 2.316472, time elapsed = 90.106416
# i = 39, khat = 1.025321, loop time = 2.238278, time elapsed = 92.344695
# i = 40, khat = 0.983088, loop time = 2.209007, time elapsed = 94.554703
# i = 41, khat = 1.023630, loop time = 2.163512, time elapsed = 96.718215
# i = 42, khat = 0.905881, loop time = 2.332882, time elapsed = 99.051097
# i = 43, khat = 0.940539, loop time = 2.186992, time elapsed = 101.238089
# i = 44, khat = 0.947277, loop time = 2.252051, time elapsed = 103.490139
# i = 45, khat = 1.035537, loop time = 2.342498, time elapsed = 105.833639
# i = 46, khat = 1.041623, loop time = 2.254129, time elapsed = 108.087768
# i = 47, khat = 0.892314, loop time = 2.398191, time elapsed = 110.486960
# i = 48, khat = 1.087864, loop time = 2.119939, time elapsed = 112.607900
# i = 49, khat = 1.004572, loop time = 2.285535, time elapsed = 114.893436
# i = 50, khat = 1.144036, loop time = 2.367540, time elapsed = 117.260976
# i = 51, khat = 1.012532, loop time = 2.330122, time elapsed = 119.591098
# i = 52, khat = 1.040994, loop time = 2.274072, time elapsed = 121.866171
# i = 53, khat = 0.970856, loop time = 2.233804, time elapsed = 124.100975
# i = 54, khat = 0.966951, loop time = 2.575608, time elapsed = 126.677586
# i = 55, khat = 1.009990, loop time = 2.317415, time elapsed = 128.996002
# i = 56, khat = 1.052582, loop time = 2.301787, time elapsed = 131.298790
# i = 57, khat = 1.071250, loop time = 2.375166, time elapsed = 133.673957
# i = 58, khat = 0.905531, loop time = 2.430213, time elapsed = 136.104170
# i = 59, khat = 1.015226, loop time = 2.339941, time elapsed = 138.445112
# i = 60, khat = 0.855360, loop time = 2.366155, time elapsed = 140.812268
# i = 61, khat = 0.906568, loop time = 2.311618, time elapsed = 143.123885
# i = 62, khat = 0.972455, loop time = 2.237825, time elapsed = 145.362712
# i = 63, khat = 1.008778, loop time = 2.089015, time elapsed = 147.451727
# i = 64, khat = 0.963929, loop time = 2.323158, time elapsed = 149.775886
# i = 65, khat = 1.009079, loop time = 2.348807, time elapsed = 152.124693
# i = 66, khat = 1.003636, loop time = 2.196005, time elapsed = 154.321698
# i = 67, khat = 0.920228, loop time = 2.360569, time elapsed = 156.683268
# i = 68, khat = 0.934389, loop time = 2.309269, time elapsed = 158.993539
# i = 69, khat = 0.857414, loop time = 2.264798, time elapsed = 161.259338
# i = 70, khat = 1.067542, loop time = 2.272062, time elapsed = 163.532402
# i = 71, khat = 1.040984, loop time = 2.204072, time elapsed = 165.737475
# i = 72, khat = 0.950304, loop time = 2.330652, time elapsed = 168.068127
# i = 73, khat = 1.046343, loop time = 2.253067, time elapsed = 170.321194
# i = 74, khat = 0.923101, loop time = 2.322022, time elapsed = 172.643217
# i = 75, khat = 1.125316, loop time = 2.163611, time elapsed = 174.806828
# i = 76, khat = 0.946826, loop time = 2.368160, time elapsed = 177.174988
# i = 77, khat = 0.914248, loop time = 2.336143, time elapsed = 179.511131
# i = 78, khat = 1.035928, loop time = 2.214214, time elapsed = 181.726345
# i = 79, khat = 0.983868, loop time = 2.170846, time elapsed = 183.897191
# i = 80, khat = 1.097651, loop time = 2.192651, time elapsed = 186.090843
# i = 81, khat = 1.049075, loop time = 2.286708, time elapsed = 188.377551
# i = 82, khat = 1.049789, loop time = 2.475861, time elapsed = 190.853412
# i = 83, khat = 1.001618, loop time = 2.473876, time elapsed = 193.327288
# i = 84, khat = 0.975646, loop time = 2.431137, time elapsed = 195.758425
# i = 85, khat = 1.041495, loop time = 2.199005, time elapsed = 197.957429
# i = 86, khat = 0.983259, loop time = 2.257574, time elapsed = 200.215003
# i = 87, khat = 0.988712, loop time = 2.440182, time elapsed = 202.655185
# i = 88, khat = 0.910933, loop time = 2.353143, time elapsed = 205.008329
# i = 89, khat = 1.006613, loop time = 2.347665, time elapsed = 207.356995
# i = 90, khat = 0.964340, loop time = 2.281541, time elapsed = 209.639522
# i = 91, khat = 0.987468, loop time = 2.264794, time elapsed = 211.904315
# i = 92, khat = 0.999665, loop time = 2.409465, time elapsed = 214.313780
# i = 93, khat = 0.933638, loop time = 2.144497, time elapsed = 216.458277
# i = 94, khat = 1.110916, loop time = 2.387258, time elapsed = 218.845535
# i = 95, khat = 0.870448, loop time = 2.422213, time elapsed = 221.267748
# i = 96, khat = 0.925799, loop time = 2.386543, time elapsed = 223.654291
# i = 97, khat = 0.957259, loop time = 2.193996, time elapsed = 225.848288
# i = 98, khat = 1.004424, loop time = 2.224964, time elapsed = 228.074252
# i = 99, khat = 0.940838, loop time = 2.354537, time elapsed = 230.429790
# Total time taken: 230.429790

# %%
np.savetxt("./data/klvi_probs_mc.csv", klvi_probs_mc, delimiter=",")
np.savetxt("./data/klvi_probs_sis.csv", klvi_probs_sis, delimiter=",")
np.savetxt("./data/klvi_probs_psis.csv", klvi_probs_psis, delimiter=",")

# %%
chivi_probs_mc = np.zeros(shape=(D+1, M))
chivi_probs_sis = np.zeros(shape=(D+1, M))
chivi_probs_psis = np.zeros(shape=(D+1, M))

# %%
start = time.time()
for i in range(M):
    start_loop = time.time()
    with open("./data/chivi_psis_"+str(i)+".pkl", 'rb') as f:
        [btemp, stemp, chivi_samples_temp, chivi_slw_temp, chivi_lw_temp, chivi_khat_temp, chivi_var_param] = pickle.load(f)
    
    scaled_weights_sis = np.exp(chivi_lw_temp - max(chivi_lw_temp))
    scaled_weights_psis = np.exp(chivi_slw_temp - max(chivi_slw_temp))
    khat_temp = chivi_khat_temp
    
    for j in range(D+1):
        prob_mc_temp = 0
        prob_sis_temp = 0
        prob_psis_temp = 0
        
        samples_temp = chivi_samples_temp[:][j]
        
        for k in range(mc_samples):
            if (j < D and samples_temp[k] < btemp[0][j]) or (j == D and np.log(samples_temp[k]) < np.log(stemp[0])):
                # unadjusted monte carlo
                prob_mc_temp += 1
                
                # sis
                prob_sis_temp += scaled_weights_sis[k]
                
                # psis
                prob_psis_temp += scaled_weights_psis[k]
                    
        chivi_probs_mc[j, i] = prob_mc_temp / mc_samples
        chivi_probs_sis[j, i] = prob_sis_temp / sum(scaled_weights_sis)
        chivi_probs_psis[j, i] = prob_psis_temp / sum(scaled_weights_psis)
    
    end_loop = time.time()
    print("i = %i, khat = %f, loop time = %f, time elapsed = %f" % (i, khat_temp, end_loop-start_loop, end_loop-start))

end = time.time()
print("Total time taken: %f" % (end-start))
# Out:
# i = 0, khat = 1.634939, loop time = 2.212591, time elapsed = 2.212591
# i = 1, khat = 1.799452, loop time = 2.251967, time elapsed = 4.464558
# i = 2, khat = 1.831626, loop time = 2.261194, time elapsed = 6.725751
# i = 3, khat = 1.896373, loop time = 2.378145, time elapsed = 9.104897
# i = 4, khat = 1.915185, loop time = 2.370159, time elapsed = 11.476057
# i = 5, khat = 1.874655, loop time = 2.165453, time elapsed = 13.642510
# i = 6, khat = 1.887969, loop time = 2.341375, time elapsed = 15.983885
# i = 7, khat = 1.817970, loop time = 2.346140, time elapsed = 18.331026
# i = 8, khat = 1.811407, loop time = 2.278446, time elapsed = 20.610473
# i = 9, khat = 1.916590, loop time = 2.416481, time elapsed = 23.026954
# i = 10, khat = 1.951602, loop time = 2.431214, time elapsed = 25.458168
# i = 11, khat = 1.856193, loop time = 2.442819, time elapsed = 27.901989
# i = 12, khat = 1.857199, loop time = 2.230381, time elapsed = 30.133370
# i = 13, khat = 1.900607, loop time = 2.199003, time elapsed = 32.332373
# i = 14, khat = 1.679801, loop time = 2.119391, time elapsed = 34.451764
# i = 15, khat = 1.823463, loop time = 2.306675, time elapsed = 36.758439
# i = 16, khat = 1.865181, loop time = 2.454234, time elapsed = 39.212673
# i = 17, khat = 1.821828, loop time = 2.445614, time elapsed = 41.658287
# i = 18, khat = 1.732273, loop time = 2.543611, time elapsed = 44.201897
# i = 19, khat = 1.858828, loop time = 2.396183, time elapsed = 46.599080
# i = 20, khat = 2.023046, loop time = 2.410546, time elapsed = 49.009626
# i = 21, khat = 1.974905, loop time = 2.097314, time elapsed = 51.106941
# i = 22, khat = 1.847924, loop time = 2.169369, time elapsed = 53.276309
# i = 23, khat = 1.823025, loop time = 2.302097, time elapsed = 55.579408
# i = 24, khat = 1.801344, loop time = 2.292421, time elapsed = 57.871829
# i = 25, khat = 1.754624, loop time = 2.289023, time elapsed = 60.161853
# i = 26, khat = 1.741676, loop time = 2.314108, time elapsed = 62.475960
# i = 27, khat = 1.774726, loop time = 2.355614, time elapsed = 64.832576
# i = 28, khat = 1.947078, loop time = 2.270481, time elapsed = 67.104057
# i = 29, khat = 1.916793, loop time = 2.489419, time elapsed = 69.593476
# i = 30, khat = 1.819830, loop time = 2.420205, time elapsed = 72.014682
# i = 31, khat = 1.667744, loop time = 2.413269, time elapsed = 74.428951
# i = 32, khat = 1.939364, loop time = 2.293564, time elapsed = 76.722515
# i = 33, khat = 1.854897, loop time = 2.474253, time elapsed = 79.196768
# i = 34, khat = 1.926827, loop time = 2.166306, time elapsed = 81.363075
# i = 35, khat = 1.736474, loop time = 2.292463, time elapsed = 83.655538
# i = 36, khat = 1.915168, loop time = 2.248049, time elapsed = 85.904587
# i = 37, khat = 1.703000, loop time = 2.254130, time elapsed = 88.159718
# i = 38, khat = 1.676508, loop time = 2.462199, time elapsed = 90.622918
# i = 39, khat = 1.893187, loop time = 2.356147, time elapsed = 92.979064
# i = 40, khat = 1.781257, loop time = 2.361360, time elapsed = 95.341424
# i = 41, khat = 1.764916, loop time = 2.240464, time elapsed = 97.581888
# i = 42, khat = 1.891073, loop time = 2.289085, time elapsed = 99.870973
# i = 43, khat = 1.953740, loop time = 2.395594, time elapsed = 102.267568
# i = 44, khat = 1.856204, loop time = 2.379731, time elapsed = 104.647299
# i = 45, khat = 1.816094, loop time = 2.241848, time elapsed = 106.889148
# i = 46, khat = 1.804704, loop time = 2.634339, time elapsed = 109.524487
# i = 47, khat = 1.808389, loop time = 2.304809, time elapsed = 111.829296
# i = 48, khat = 1.697465, loop time = 2.259057, time elapsed = 114.088353
# i = 49, khat = 1.995906, loop time = 2.319176, time elapsed = 116.408530
# i = 50, khat = 2.044116, loop time = 2.501950, time elapsed = 118.910480
# i = 51, khat = 1.743189, loop time = 2.320113, time elapsed = 121.230593
# i = 52, khat = 1.844122, loop time = 2.353647, time elapsed = 123.585241
# i = 53, khat = 1.872520, loop time = 2.569795, time elapsed = 126.156037
# i = 54, khat = 1.875674, loop time = 2.294132, time elapsed = 128.450169
# i = 55, khat = 1.838514, loop time = 2.367156, time elapsed = 130.817325
# i = 56, khat = 1.838467, loop time = 2.266817, time elapsed = 133.084142
# i = 57, khat = 1.813992, loop time = 2.293792, time elapsed = 135.377934
# i = 58, khat = 1.912178, loop time = 2.426209, time elapsed = 137.804143
# i = 59, khat = 2.004705, loop time = 2.438618, time elapsed = 140.242761
# i = 60, khat = 1.876074, loop time = 2.296776, time elapsed = 142.539537
# i = 61, khat = 1.668951, loop time = 2.237037, time elapsed = 144.776574
# i = 62, khat = 1.963330, loop time = 2.416761, time elapsed = 147.193336
# i = 63, khat = 1.799196, loop time = 2.015914, time elapsed = 149.209764
# i = 64, khat = 1.703832, loop time = 2.255054, time elapsed = 151.465819
# i = 65, khat = 1.841278, loop time = 2.300731, time elapsed = 153.766551
# i = 66, khat = 1.970133, loop time = 2.448975, time elapsed = 156.215525
# i = 67, khat = 1.707300, loop time = 2.486011, time elapsed = 158.701537
# i = 68, khat = 1.921686, loop time = 2.269066, time elapsed = 160.971603
# i = 69, khat = 1.817904, loop time = 2.315517, time elapsed = 163.287120
# i = 70, khat = 1.637241, loop time = 2.320444, time elapsed = 165.607563
# i = 71, khat = 1.805357, loop time = 2.305103, time elapsed = 167.912666
# i = 72, khat = 1.810608, loop time = 2.319737, time elapsed = 170.232404
# i = 73, khat = 1.546653, loop time = 2.327958, time elapsed = 172.560361
# i = 74, khat = 1.762867, loop time = 2.342132, time elapsed = 174.902493
# i = 75, khat = 1.846657, loop time = 2.190500, time elapsed = 177.093994
# i = 76, khat = 1.818562, loop time = 2.266847, time elapsed = 179.360841
# i = 77, khat = 1.864904, loop time = 2.318110, time elapsed = 181.679952
# i = 78, khat = 1.767294, loop time = 2.355491, time elapsed = 184.035443
# i = 79, khat = 1.860977, loop time = 2.300763, time elapsed = 186.336207
# i = 80, khat = 1.735896, loop time = 2.301580, time elapsed = 188.638788
# i = 81, khat = 1.863666, loop time = 2.360834, time elapsed = 190.999621
# i = 82, khat = 1.955825, loop time = 2.363021, time elapsed = 193.362643
# i = 83, khat = 1.758969, loop time = 2.332989, time elapsed = 195.696633
# i = 84, khat = 1.829284, loop time = 2.409196, time elapsed = 198.106831
# i = 85, khat = 1.922856, loop time = 2.298896, time elapsed = 200.405727
# i = 86, khat = 1.881185, loop time = 2.217918, time elapsed = 202.623645
# i = 87, khat = 1.754417, loop time = 2.353152, time elapsed = 204.976798
# i = 88, khat = 1.780810, loop time = 2.358148, time elapsed = 207.335946
# i = 89, khat = 1.703787, loop time = 2.243999, time elapsed = 209.579945
# i = 90, khat = 1.710670, loop time = 2.481260, time elapsed = 212.061204
# i = 91, khat = 1.874607, loop time = 2.325204, time elapsed = 214.386408
# i = 92, khat = 1.848431, loop time = 2.323666, time elapsed = 216.710074
# i = 93, khat = 1.745039, loop time = 2.312111, time elapsed = 219.022185
# i = 94, khat = 1.690738, loop time = 2.360990, time elapsed = 221.383175
# i = 95, khat = 1.868542, loop time = 2.254054, time elapsed = 223.637229
# i = 96, khat = 1.883232, loop time = 2.399116, time elapsed = 226.037345
# i = 97, khat = 1.770474, loop time = 2.527091, time elapsed = 228.564436
# i = 98, khat = 1.672984, loop time = 2.257056, time elapsed = 230.821492
# i = 99, khat = 1.812390, loop time = 2.445713, time elapsed = 233.268205
# Total time taken: 233.269206

# %%
np.savetxt("./data/chivi_probs_mc.csv", chivi_probs_mc, delimiter=",")
np.savetxt("./data/chivi_probs_sis.csv", chivi_probs_sis, delimiter=",")
np.savetxt("./data/chivi_probs_psis.csv", chivi_probs_psis, delimiter=",")
